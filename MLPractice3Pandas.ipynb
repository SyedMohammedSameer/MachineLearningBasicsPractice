# %% [markdown]
# ***A Quick Python Pandas Tutorial by Sameer***

# %% [markdown]
# 1. Introduction to Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 2. DataFrames and Series

# %%
s=pd.Series([1,2,3,4,5,6,np.nan,8,9,10])
s
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     9.0
# 9    10.0
# dtype: float64

# %%
d=pd.date_range('20200301',periods=10)
d
# Out:
# DatetimeIndex(['2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04',
#                '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08',
#                '2020-03-09', '2020-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df=pd.DataFrame(np.random.randn(10,4),index=d,columns=['A','B','C','D'])
df
# Out:
#                    A         B         C         D
# 2020-03-01 -1.383226  2.027394 -0.374115 -1.788337
# 2020-03-02 -0.041375  1.001880 -0.458182  2.034568
# 2020-03-03  0.261624 -0.364776  0.361187  1.227566
# 2020-03-04  0.000625 -0.393302 -1.491398  0.818988
# 2020-03-05 -1.549629 -0.915159 -0.303642  1.299053
# 2020-03-06  0.751398  1.721046 -0.478334 -1.231237
# 2020-03-07  1.950087 -1.299978 -0.825190 -0.237024
# 2020-03-08  0.208823 -1.609865  1.529870 -0.179092
# 2020-03-09 -1.820360 -0.843848 -0.249277 -0.626639
# 2020-03-10 -1.483504 -0.456218 -0.750815 -0.300766

# %%
df1=pd.DataFrame({'A':[1,2,3,4],'B':pd.Timestamp('20200301'),'C':pd.Series(1,index=list(range(4)),dtype='float32'),'D':np.array([5]*4,dtype='int32'),'E':pd.Categorical(['true','false','True','False']),'F':'Edureka'})

# %%
df1
# Out:
#    A          B    C  D      E        F
# 0  1 2020-03-01  1.0  5   true  Edureka
# 1  2 2020-03-01  1.0  5  false  Edureka
# 2  3 2020-03-01  1.0  5   True  Edureka
# 3  4 2020-03-01  1.0  5  False  Edureka

# %%
df1.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# 3. To View and selecting Data

# %%
df.head()
# Out:
#                    A         B         C         D
# 2020-03-01  0.553252 -0.512778 -0.201328  0.389890
# 2020-03-02  0.622303  0.667711  0.260653  1.319603
# 2020-03-03 -1.019797  2.377668 -0.553818 -0.071236
# 2020-03-04 -0.818660  2.154392 -0.208261 -0.557627
# 2020-03-05 -0.962466  1.629185  1.903499 -1.008904

# %%
df.tail()
# Out:
#                    A         B         C         D
# 2020-03-06  1.399467 -1.106326 -0.244138 -0.070930
# 2020-03-07  1.053423 -0.384689 -2.134924  0.638766
# 2020-03-08 -0.001848  0.598483  0.247066  0.740873
# 2020-03-09 -0.209236  0.110301  0.403189 -0.988602
# 2020-03-10  1.393907 -0.752605 -0.150945  2.216104

# %%
df.index
# Out:
# DatetimeIndex(['2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04',
#                '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08',
#                '2020-03-09', '2020-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 5.53252030e-01, -5.12777546e-01, -2.01327975e-01,
#          3.89890185e-01],
#        [ 6.22302617e-01,  6.67710684e-01,  2.60653275e-01,
#          1.31960342e+00],
#        [-1.01979710e+00,  2.37766800e+00, -5.53818224e-01,
#         -7.12360654e-02],
#        [-8.18660159e-01,  2.15439150e+00, -2.08260519e-01,
#         -5.57626784e-01],
#        [-9.62465597e-01,  1.62918526e+00,  1.90349893e+00,
#         -1.00890408e+00],
#        [ 1.39946718e+00, -1.10632589e+00, -2.44138020e-01,
#         -7.09299042e-02],
#        [ 1.05342259e+00, -3.84688840e-01, -2.13492448e+00,
#          6.38765606e-01],
#        [-1.84832590e-03,  5.98482552e-01,  2.47066393e-01,
#          7.40873457e-01],
#        [-2.09235854e-01,  1.10301372e-01,  4.03188782e-01,
#         -9.88601606e-01],
#        [ 1.39390735e+00, -7.52605229e-01, -1.50945324e-01,
#          2.21610431e+00]])

# %%
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.201034   0.478134  -0.067901   0.260794
# std     0.941671   1.232897   0.994410   1.021847
# min    -1.019797  -1.106326  -2.134924  -1.008904
# 25%    -0.666304  -0.480755  -0.235169  -0.436029
# 50%     0.275702   0.354392  -0.176137   0.159480
# 75%     0.945643   1.388817   0.257257   0.715346
# max     1.399467   2.377668   1.903499   2.216104

# %%
df.sort_index( )
# Out:
#                    A         B         C         D
# 2020-03-01  0.553252 -0.512778 -0.201328  0.389890
# 2020-03-02  0.622303  0.667711  0.260653  1.319603
# 2020-03-03 -1.019797  2.377668 -0.553818 -0.071236
# 2020-03-04 -0.818660  2.154392 -0.208261 -0.557627
# 2020-03-05 -0.962466  1.629185  1.903499 -1.008904
# 2020-03-06  1.399467 -1.106326 -0.244138 -0.070930
# 2020-03-07  1.053423 -0.384689 -2.134924  0.638766
# 2020-03-08 -0.001848  0.598483  0.247066  0.740873
# 2020-03-09 -0.209236  0.110301  0.403189 -0.988602
# 2020-03-10  1.393907 -0.752605 -0.150945  2.216104

# %%
df.sort_values(by='C')
# Out:
#                    A         B         C         D
# 2020-03-07  1.053423 -0.384689 -2.134924  0.638766
# 2020-03-03 -1.019797  2.377668 -0.553818 -0.071236
# 2020-03-06  1.399467 -1.106326 -0.244138 -0.070930
# 2020-03-04 -0.818660  2.154392 -0.208261 -0.557627
# 2020-03-01  0.553252 -0.512778 -0.201328  0.389890
# 2020-03-10  1.393907 -0.752605 -0.150945  2.216104
# 2020-03-08 -0.001848  0.598483  0.247066  0.740873
# 2020-03-02  0.622303  0.667711  0.260653  1.319603
# 2020-03-09 -0.209236  0.110301  0.403189 -0.988602
# 2020-03-05 -0.962466  1.629185  1.903499 -1.008904

# %%
df['C']
# Out:
# 2020-03-01   -0.201328
# 2020-03-02    0.260653
# 2020-03-03   -0.553818
# 2020-03-04   -0.208261
# 2020-03-05    1.903499
# 2020-03-06   -0.244138
# 2020-03-07   -2.134924
# 2020-03-08    0.247066
# 2020-03-09    0.403189
# 2020-03-10   -0.150945
# Freq: D, Name: C, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2020-03-01  0.553252 -0.512778 -0.201328  0.389890
# 2020-03-02  0.622303  0.667711  0.260653  1.319603
# 2020-03-03 -1.019797  2.377668 -0.553818 -0.071236

# %%
df.loc[d[0]]
# Out:
# A    0.553252
# B   -0.512778
# C   -0.201328
# D    0.389890
# Name: 2020-03-01 00:00:00, dtype: float64

# %%
df.loc[:,['A','C']]
# Out:
#                    A         C
# 2020-03-01  0.553252 -0.201328
# 2020-03-02  0.622303  0.260653
# 2020-03-03 -1.019797 -0.553818
# 2020-03-04 -0.818660 -0.208261
# 2020-03-05 -0.962466  1.903499
# 2020-03-06  1.399467 -0.244138
# 2020-03-07  1.053423 -2.134924
# 2020-03-08 -0.001848  0.247066
# 2020-03-09 -0.209236  0.403189
# 2020-03-10  1.393907 -0.150945

# %%
df.loc['20200306',['D','C']]
# Out:
# D   -0.070930
# C   -0.244138
# Name: 2020-03-06 00:00:00, dtype: float64

# %%
df.loc[d[0],['D','C']]
# Out:
# D    0.389890
# C   -0.201328
# Name: 2020-03-01 00:00:00, dtype: float64

# %%
df.at[d[0],'C']
# Out:
# -0.20132797461531604

# %%
df.iloc[3]
# Out:
# A   -0.818660
# B    2.154392
# C   -0.208261
# D   -0.557627
# Name: 2020-03-04 00:00:00, dtype: float64

# %%
df[df['A']>0]
# Out:
#                    A         B         C         D
# 2020-03-01  0.553252 -0.512778 -0.201328  0.389890
# 2020-03-02  0.622303  0.667711  0.260653  1.319603
# 2020-03-06  1.399467 -1.106326 -0.244138 -0.070930
# 2020-03-07  1.053423 -0.384689 -2.134924  0.638766
# 2020-03-10  1.393907 -0.752605 -0.150945  2.216104

# %% [markdown]
# Null Data Handling

# %%
#Creating a new index
df2=df.reindex(index=d[0:4],columns=list(df.columns)+['E'])

# %%
df2.loc[d[0]:d[1],'E']=1
df2
# Out:
#                    A         B         C         D    E
# 2020-03-01 -0.756616 -0.446858 -0.265370 -0.815680  1.0
# 2020-03-02 -0.399590  0.510236 -0.248334  0.881842  1.0
# 2020-03-03  0.540897  0.660069 -1.162740  1.249226  NaN
# 2020-03-04 -0.062414  0.223763  0.835557 -0.225396  NaN

# %%
df2.isnull()
# Out:
#                 A      B      C      D      E
# 2020-03-01  False  False  False  False  False
# 2020-03-02  False  False  False  False  False
# 2020-03-03  False  False  False  False   True
# 2020-03-04  False  False  False  False   True

# %%
df2.isnull().count()
# Out:
# A    4
# B    4
# C    4
# D    4
# E    4
# dtype: int64

# %%
#Drops layer of Null Value
df2.dropna()
# Out:
#                    A         B         C         D    E
# 2020-03-01 -0.756616 -0.446858 -0.265370 -0.815680  1.0
# 2020-03-02 -0.399590  0.510236 -0.248334  0.881842  1.0

# %%
df2
# Out:
#                    A         B         C         D    E
# 2020-03-01 -0.756616 -0.446858 -0.265370 -0.815680  1.0
# 2020-03-02 -0.399590  0.510236 -0.248334  0.881842  1.0
# 2020-03-03  0.540897  0.660069 -1.162740  1.249226  NaN
# 2020-03-04 -0.062414  0.223763  0.835557 -0.225396  NaN

# %%
#Filling Null with values
df2.fillna(value=2)
# Out:
#                    A         B         C         D    E
# 2020-03-01 -0.756616 -0.446858 -0.265370 -0.815680  1.0
# 2020-03-02 -0.399590  0.510236 -0.248334  0.881842  1.0
# 2020-03-03  0.540897  0.660069 -1.162740  1.249226  2.0
# 2020-03-04 -0.062414  0.223763  0.835557 -0.225396  2.0

# %%
pd.isna(df2)  #BooleanMask
# Out:
#                 A      B      C      D      E
# 2020-03-01  False  False  False  False  False
# 2020-03-02  False  False  False  False  False
# 2020-03-03  False  False  False  False   True
# 2020-03-04  False  False  False  False   True

# %% [markdown]
# 4. Different Pandas Operations

# %%
df.mean()
# Out:
# A   -0.130765
# B   -0.190671
# C    0.047213
# D    0.288277
# dtype: float64

# %%
df.mean(1)
# Out:
# 2020-03-01   -0.571131
# 2020-03-02    0.186039
# 2020-03-03    0.321863
# 2020-03-04    0.192877
# 2020-03-05   -0.190672
# 2020-03-06    0.348122
# 2020-03-07   -0.032236
# 2020-03-08   -0.264296
# 2020-03-09    0.375970
# 2020-03-10   -0.331400
# Freq: D, dtype: float64

# %%
 s=pd.Series([1,2,3,np.nan,4,5,6,7,8,9],index=d).shift(2)
 s
# Out:
# 2020-03-01    NaN
# 2020-03-02    NaN
# 2020-03-03    1.0
# 2020-03-04    2.0
# 2020-03-05    3.0
# 2020-03-06    NaN
# 2020-03-07    4.0
# 2020-03-08    5.0
# 2020-03-09    6.0
# 2020-03-10    7.0
# Freq: D, dtype: float64

# %%
df.sub(s,axis='index')
# Out:
#                    A         B         C         D
# 2020-03-01       NaN       NaN       NaN       NaN
# 2020-03-02       NaN       NaN       NaN       NaN
# 2020-03-03 -0.459103 -0.339931 -2.162740  0.249226
# 2020-03-04 -2.062414 -1.776237 -1.164443 -2.225396
# 2020-03-05 -3.152542 -4.399202 -2.358969 -2.851976
# 2020-03-06       NaN       NaN       NaN       NaN
# 2020-03-07 -3.803918 -4.058145 -5.050883 -3.215999
# 2020-03-08 -6.327770 -6.220859 -4.344243 -4.164312
# 2020-03-09 -5.244784 -6.437641 -5.773032 -5.040665
# 2020-03-10 -6.989211 -8.607294 -7.567775 -6.161321

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C         D
# 2020-03-01 -0.756616 -0.446858 -0.265370 -0.815680
# 2020-03-02 -1.156206  0.063378 -0.513704  0.066163
# 2020-03-03 -0.615309  0.723448 -1.676444  1.315389
# 2020-03-04 -0.677723  0.947210 -0.840887  1.089993
# 2020-03-05 -0.830265 -0.451992 -0.199856  1.238017
# 2020-03-06 -0.941970  1.417233  1.208064 -0.534935
# 2020-03-07 -0.745889  1.359088  0.157181  0.249067
# 2020-03-08 -2.073658  0.138229  0.812938  1.084754
# 2020-03-09 -1.318442 -0.299412  1.039906  2.044090
# 2020-03-10 -1.307653 -1.906706  0.472131  2.882768

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.082986
# B    3.476519
# C    2.570660
# D    3.022178
# dtype: float64

# %%
s.value_counts()
# Out:
# 7.0    1
# 6.0    1
# 5.0    1
# 4.0    1
# 3.0    1
# 2.0    1
# 1.0    1
# dtype: int64

# %%
s=pd.Series(['edureka','python','jupyter',np.nan,'cricket','world'])

# %%
s.str.upper()
# Out:
# 0    EDUREKA
# 1     PYTHON
# 2    JUPYTER
# 3        NaN
# 4    CRICKET
# 5      WORLD
# dtype: object

# %%
df=pd.DataFrame(np.random.randn(10,4))

# %%
df2=[df[:3],df[3:7],df[7:]]

# %%
pd.concat(df2)
# Out:
#           0         1         2         3
# 0 -0.155507 -0.242322  1.091241  1.015908
# 1  1.125367  0.349453  0.018605 -0.030992
# 2 -1.873380  0.901418 -1.718011  0.747441
# 3  0.577925  1.236638 -0.313782 -0.394203
# 4 -0.240628  0.227733 -0.383891 -1.017611
# 5  1.038839 -1.248350 -1.173643  1.706267
# 6  1.543234 -0.831735  1.449266  0.735503
# 7 -0.313738  0.820949  0.646331  1.290868
# 8 -0.181093 -0.810627  0.395023  1.404965
# 9  1.337133  0.588914  0.624374 -1.026014

# %%
left=pd.DataFrame({'A':[1,2],'B':[3,4]})

# %%
left
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
right=pd.DataFrame({'A':[5,6],'D':[7,8]})

# %%
right
# Out:
#    A  D
# 0  5  7
# 1  6  8

# %%
pd.merge(left,right,on='A')
# Out:
# Empty DataFrame
# Columns: [A, B, D]
# Index: []

# %%
df
# Out:
#           0         1         2         3
# 0 -0.155507 -0.242322  1.091241  1.015908
# 1  1.125367  0.349453  0.018605 -0.030992
# 2 -1.873380  0.901418 -1.718011  0.747441
# 3  0.577925  1.236638 -0.313782 -0.394203
# 4 -0.240628  0.227733 -0.383891 -1.017611
# 5  1.038839 -1.248350 -1.173643  1.706267
# 6  1.543234 -0.831735  1.449266  0.735503
# 7 -0.313738  0.820949  0.646331  1.290868
# 8 -0.181093 -0.810627  0.395023  1.404965
# 9  1.337133  0.588914  0.624374 -1.026014

# %%
df.groupby(2).sum()
# Out:
#                   0         1         3
# 2
# -1.718011 -1.873380  0.901418  0.747441
# -1.173643  1.038839 -1.248350  1.706267
# -0.383891 -0.240628  0.227733 -1.017611
# -0.313782  0.577925  1.236638 -0.394203
#  0.018605  1.125367  0.349453 -0.030992
#  0.395023 -0.181093 -0.810627  1.404965
#  0.624374  1.337133  0.588914 -1.026014
#  0.646331 -0.313738  0.820949  1.290868
#  1.091241 -0.155507 -0.242322  1.015908
#  1.449266  1.543234 -0.831735  0.735503

# %%
df.groupby([2,3]).sum()
# Out:
#                             0         1
# 2         3
# -1.718011  0.747441 -1.873380  0.901418
# -1.173643  1.706267  1.038839 -1.248350
# -0.383891 -1.017611 -0.240628  0.227733
# -0.313782 -0.394203  0.577925  1.236638
#  0.018605 -0.030992  1.125367  0.349453
#  0.395023  1.404965 -0.181093 -0.810627
#  0.624374 -1.026014  1.337133  0.588914
#  0.646331  1.290868 -0.313738  0.820949
#  1.091241  1.015908 -0.155507 -0.242322
#  1.449266  0.735503  1.543234 -0.831735

# %%
my_tuple=list(zip(*[[1,2,3,4,5,11,12,13],[6,7,8,9,10,14,15,16]]))

# %%
index=pd.MultiIndex.from_tuples(my_tuple,names=['First','Second'])

# %%
df=pd.DataFrame(np.random.randn(8,2),index=index,columns=['A','B'])

# %%
df2=df[:4]

# %%
df2
# Out:
#                      A         B
# First Second
# 1     6       0.432540 -0.513155
# 2     7      -1.743583 -0.865054
# 3     8      -1.014597 -0.459072
# 4     9       1.230573 -1.320862

# %%
a=df2.stack()

# %%
a=df2.unstack()

# %%
df=pd.DataFrame({'A':['a','b','c','d']*3,
                 'B':['A','B','C']*4,
                 'C':['P','P','P','Q','Q','Q']*2,
                 'D':np.random.randn(12),
                 'E':np.random.randn(12)})

# %%
df
# Out:
#     A  B  C         D         E
# 0   a  A  P  0.612898  0.284240
# 1   b  B  P -0.212551 -0.342059
# 2   c  C  P -0.762454  0.334660
# 3   d  A  Q -0.937866  1.285850
# 4   a  B  Q  0.505718  1.368248
# 5   b  C  Q -0.298118 -2.066776
# 6   c  A  P -0.360585 -3.506801
# 7   d  B  P  2.168034 -0.964048
# 8   a  C  P -0.524270 -0.307123
# 9   b  A  Q -0.398075  0.022364
# 10  c  B  Q  0.098742  1.529184
# 11  d  C  Q  0.133518 -0.748572

# %%
pd.pivot_table(df,values='D',index=['A','B'],columns='C')
# Out:
# C           P         Q
# A B
# a A  0.612898       NaN
#   B       NaN  0.505718
#   C -0.524270       NaN
# b A       NaN -0.398075
#   B -0.212551       NaN
#   C       NaN -0.298118
# c A -0.360585       NaN
#   B       NaN  0.098742
#   C -0.762454       NaN
# d A       NaN -0.937866
#   B  2.168034       NaN
#   C       NaN  0.133518

# %%
dates=pd.date_range('03/03/2020',periods=100,freq='S')
dates
# Out:
# DatetimeIndex(['2020-03-03 00:00:00', '2020-03-03 00:00:01',
#                '2020-03-03 00:00:02', '2020-03-03 00:00:03',
#                '2020-03-03 00:00:04', '2020-03-03 00:00:05',
#                '2020-03-03 00:00:06', '2020-03-03 00:00:07',
#                '2020-03-03 00:00:08', '2020-03-03 00:00:09',
#                '2020-03-03 00:00:10', '2020-03-03 00:00:11',
#                '2020-03-03 00:00:12', '2020-03-03 00:00:13',
#                '2020-03-03 00:00:14', '2020-03-03 00:00:15',
#                '2020-03-03 00:00:16', '2020-03-03 00:00:17',
#                '2020-03-03 00:00:18', '2020-03-03 00:00:19',
#                '2020-03-03 00:00:20', '2020-03-03 00:00:21',
#                '2020-03-03 00:00:22', '2020-03-03 00:00:23',
#                '2020-03-03 00:00:24', '2020-03-03 00:00:25',
#                '2020-03-03 00:00:26', '2020-03-03 00:00:27',
#                '2020-03-03 00:00:28', '2020-03-03 00:00:29',
# ...

# %%
ts=pd.Series(np.random.randint(0,500,len(dates)),dates)

# %%
ts.resample('5min').sum()
# Out:
# 2020-03-03    26317
# Freq: 5T, dtype: int64

# %%
dates=pd.date_range('03/03/2020 00:00',periods=5,freq='S')
dates
# Out:
# DatetimeIndex(['2020-03-03 00:00:00', '2020-03-03 00:00:01',
#                '2020-03-03 00:00:02', '2020-03-03 00:00:03',
#                '2020-03-03 00:00:04'],
#               dtype='datetime64[ns]', freq='S')

# %%
ts=pd.Series(np.random.randn(len(dates)),dates)
ts
# Out:
# 2020-03-03 00:00:00    2.191200
# 2020-03-03 00:00:01   -0.102267
# 2020-03-03 00:00:02   -0.943441
# 2020-03-03 00:00:03    0.007307
# 2020-03-03 00:00:04    1.340648
# Freq: S, dtype: float64

# %%
ts_utc=ts.tz_localize('UTC')

# %%
ts_utc
# Out:
# 2020-03-03 00:00:00+00:00    2.191200
# 2020-03-03 00:00:01+00:00   -0.102267
# 2020-03-03 00:00:02+00:00   -0.943441
# 2020-03-03 00:00:03+00:00    0.007307
# 2020-03-03 00:00:04+00:00    1.340648
# Freq: S, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2020-03-02 19:00:00-05:00    2.191200
# 2020-03-02 19:00:01-05:00   -0.102267
# 2020-03-02 19:00:02-05:00   -0.943441
# 2020-03-02 19:00:03-05:00    0.007307
# 2020-03-02 19:00:04-05:00    1.340648
# Freq: S, dtype: float64

# %%
df=pd.DataFrame({'id':[1,2,3,4,5],
                 "grade":['a','b','a','d','a']
                 })
df
# Out:
#    id grade
# 0   1     a
# 1   2     b
# 2   3     a
# 3   4     d
# 4   5     a

# %%
df['Grade']=df['grade'].astype("category")
df['Grade']
# Out:
# 0         good
# 1    very good
# 2         good
# 3          bad
# 4         good
# Name: Grade, dtype: category
# Categories (3, object): ['good', 'very good', 'bad']

# %%
df['Grade'].cat.categories=['good','very good','bad']

# %%
df['Grade']=df['grade'].cat.set_categories(['very good','bad','very bad','good','average'])

# %%
df['Grade']
# Out:
# 0         good
# 1    very good
# 2         good
# 3          bad
# 4         good
# Name: Grade, dtype: category
# Categories (5, object): ['very good', 'bad', 'very bad', 'good', 'average']

# %% [markdown]
# 5. Plotting with Python

# %%
import matplotlib.pyplot as plt

# %%
plt.close('all')

# %%
ts=pd.Series(np.random.randn(500),index=pd.date_range('1/2/2020',periods=500))

# %%
ts=ts.cumsum()

# %%
ts.plot()

# %% [markdown]
# 6. Reading and Writing using Pandas

# %%
ts.to_csv("ts.csv")

# %% [markdown]
# Or we can use directory path
